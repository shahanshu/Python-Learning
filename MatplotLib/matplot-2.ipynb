# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
#figues and axis 
#figue is like the area to be plotted and then the axis is the 
#Axes are the actual plots (graphs) inside the Figure. ( may be two or mow)
#it;s more like a subplots(obkect) of plt

# %%
fig,ax=plt.subplots()
x=np.linspace(-10,10,200)
y=x**2
ax.plot(x,y,label='test curve',color='red')
ax.set_xlabel('X-asix')
ax.set_ylabel('Y-asis')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with 2 rows and 2 columns of subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

# Plot data on each subplot
x = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
y2 = [30, 25, 20, 10]
y3 = [15, 25, 35, 45]
y4 = [45, 35, 25, 15]

axes[0, 0].plot(x, y1, label='Plot 1')
axes[0, 0].set_title('Plot 1')

axes[0, 1].scatter(x, y2, color='red', label='Plot 2')
axes[0, 1].set_title('Plot 2')

axes[1, 0].bar(x, y3, color='green', label='Plot 3')
axes[1, 0].set_title('Plot 3')

axes[1, 1].hist(y4, bins=5, color='purple', label='Plot 4')
axes[1, 1].set_title('Plot 4')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
