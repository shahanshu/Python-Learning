# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...

# %%
df.size
# Out:
# 240640

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Country or territory name ISO 2-character country/territory code  \
# 0                  Afghanistan                                     AF
# 1                  Afghanistan                                     AF
# 2                  Afghanistan                                     AF
# 3                  Afghanistan                                     AF
# 4                  Afghanistan                                     AF
# ...                        ...                                    ...
# 5115                  Zimbabwe                                     ZW
# 5116                  Zimbabwe                                     ZW
# 5117                  Zimbabwe                                     ZW
# 5118                  Zimbabwe                                     ZW
# 5119                  Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5120, step=1)

# %%
df.shape
# Out:
# (5120, 47)

# %%
nepal_stat = 'Nepal' in df['Country or territory name'].values

# %%
print(nepal_stat)
# Out:
# True

# %%
df[df['Country or territory name'] == 'Nepal']
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 3137                     Nepal                                     NP
# 3138                     Nepal                                     NP
# 3139                     Nepal                                     NP
# 3140                     Nepal                                     NP
# 3141                     Nepal                                     NP
# 3142                     Nepal                                     NP
# 3143                     Nepal                                     NP
# 3144                     Nepal                                     NP
# 3145                     Nepal                                     NP
# 3146                     Nepal                                     NP
# 3147                     Nepal                                     NP
# 3148                     Nepal                                     NP
# ...
