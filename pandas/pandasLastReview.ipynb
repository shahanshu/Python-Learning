# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd

# %%
dict={

    'name': ['anshu ','aman','junu','anu'],
    'age':[2,3,4,54]
}

# %%
anshu= pd.Series(dict )
print(anshu)
# Out:
# name    [anshu , aman, junu, anu]
# age                 [2, 3, 4, 54]
# dtype: object

# %%
import pandas as pd

# Dictionary
data = {'a': 10, 'b': 20, 'c': 30}

# Create Series
series = pd.Series(data)

print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
dict = {
    'name':'anshu', 
    'age':22
}

# %%
pd.Series(dict)
# Out:
# name    anshu
# age        22
# dtype: object

# %%
sibs={
    'name':['anshu','aman','junu','anu'],
    'add':['dharan','ktm','ktm',np.nan]
}

# %%
pd.DataFrame(sibs)
# Out:
#     name     add
# 0  anshu  dharan
# 1   aman     ktm
# 2   junu     ktm
# 3    anu     NaN

# %%
students = pd.DataFrame({
    'Name': ['Anshu', 'Aman', 'Junu', 'Anu'],
    'Age': [20, 21, 22, 23],
    'Grade': ['A', 'B', 'A', 'C'],
    'City': ['Dharan', 'KTM', 'KTM', 'Biratnagar']
})

# %%
df= pd.DataFrame(students)

# %%
df
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 1   Aman   21     B         KTM
# 2   Junu   22     A         KTM
# 3    Anu   23     C  Biratnagar

# %%
pd.DataFrame(data=df,columns=['name'])
# Out:
#    name
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN

# %%
df
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 1   Aman   21     B         KTM
# 2   Junu   22     A         KTM
# 3    Anu   23     C  Biratnagar

# %%
pd.DataFrame(df,columns=['Name','Grade'])
# Out:
#     Name Grade
# 0  Anshu     A
# 1   Aman     B
# 2   Junu     A
# 3    Anu     C

# %%
df[['Name',"Grade"]]
# Out:
#     Name Grade
# 0  Anshu     A
# 1   Aman     B
# 2   Junu     A
# 3    Anu     C

# %%
df
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 1   Aman   21     B         KTM
# 2   Junu   22     A         KTM
# 3    Anu   23     C  Biratnagar

# %%
df.loc[0]
# Out:
# Name      Anshu
# Age          20
# Grade         A
# City     Dharan
# Name: 0, dtype: object

# %%
df.loc[[0,3]]
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 3    Anu   23     C  Biratnagar

# %%
df
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 1   Aman   21     B         KTM
# 2   Junu   22     A         KTM
# 3    Anu   23     C  Biratnagar

# %%
df.loc[[2,3]][['Grade',"Name"]]
# Out:
#   Grade  Name
# 2     A  Junu
# 3     C   Anu

# %%
df
# Out:
#     Name  Age Grade        City
# 0  Anshu   20     A      Dharan
# 1   Aman   21     B         KTM
# 2   Junu   22     A         KTM
# 3    Anu   23     C  Biratnagar

# %%
df[df['Age']> 22]
# Out:
#   Name  Age Grade        City
# 3  Anu   23     C  Biratnagar

# %%
df[df['City']=='KTM']
# Out:
#    Name  Age Grade City
# 1  Aman   21     B  KTM
# 2  Junu   22     A  KTM

# %%
df[df["Age"]<23]
# Out:
#     Name  Age Grade    City
# 0  Anshu   20     A  Dharan
# 1   Aman   21     B     KTM
# 2   Junu   22     A     KTM

# %%
df['status']=(df["Age"]>22) | (df['City']=="KTM")

# %%
df
# Out:
#     Name  Age Grade        City  status
# 0  Anshu   20     A      Dharan   False
# 1   Aman   21     B         KTM    True
# 2   Junu   22     A         KTM    True
# 3    Anu   23     C  Biratnagar    True

# %%
df['NewCol']=[False,True,False,True]

# %%
df
# Out:
#     Name  Age Grade        City  status  NewCol
# 0  Anshu   20     A      Dharan   False   False
# 1   Aman   21     B         KTM    True    True
# 2   Junu   22     A         KTM    True   False
# 3    Anu   23     C  Biratnagar    True    True

# %%
df
# Out:
#     Name  Age Grade        City  status  NewCol
# 0  Anshu   20     A      Dharan   False   False
# 1   Aman   21     B         KTM    True    True
# 2   Junu   22     A         KTM    True   False
# 3    Anu   23     C  Biratnagar    True    True

# %%
df['salary']=[np.nan,30,23,12]

# %%
df
# Out:
#     Name  Age Grade        City  status  NewCol  salary
# 0  Anshu   20     A      Dharan   False   False     NaN
# 1   Aman   21     B         KTM    True    True    30.0
# 2   Junu   22     A         KTM    True   False    23.0
# 3    Anu   23     C  Biratnagar    True    True    12.0

# %%
df.isna()
# Out:
#     Name    Age  Grade   City  status  NewCol  salary
# 0  False  False  False  False   False   False    True
# 1  False  False  False  False   False   False   False
# 2  False  False  False  False   False   False   False
# 3  False  False  False  False   False   False   False

# %%
df.isna().sum()
# Out:
# Name      0
# Age       0
# Grade     0
# City      0
# status    0
# NewCol    0
# salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#    Name  Age Grade        City  status  NewCol  salary
# 1  Aman   21     B         KTM    True    True    30.0
# 2  Junu   22     A         KTM    True   False    23.0
# 3   Anu   23     C  Biratnagar    True    True    12.0

# %%
df
# Out:
#     Name  Age Grade        City  status  NewCol  salary
# 0  Anshu   20     A      Dharan   False   False     NaN
# 1   Aman   21     B         KTM    True    True    30.0
# 2   Junu   22     A         KTM    True   False    23.0
# 3    Anu   23     C  Biratnagar    True    True    12.0

# %%
df.dropna(thresh=2)
# Out:
#     Name  Age Grade        City  status  NewCol  salary
# 0  Anshu   20     A      Dharan   False   False     NaN
# 1   Aman   21     B         KTM    True    True    30.0
# 2   Junu   22     A         KTM    True   False    23.0
# 3    Anu   23     C  Biratnagar    True    True    12.0

# %%
df.fillna(2)
# Out:
#     Name  Age Grade        City  status  NewCol  salary
# 0  Anshu   20     A      Dharan   False   False     2.0
# 1   Aman   21     B         KTM    True    True    30.0
# 2   Junu   22     A         KTM    True   False    23.0
# 3    Anu   23     C  Biratnagar    True    True    12.0

# %%
data = {
    'Salesperson': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob', 'Charlie', 'Alice'],
    'Region': ['North', 'North', 'South', 'South', 'North', 'South', 'North'],
    'Product': ['Laptop', 'Laptop', 'Mouse', 'Mouse', 'Laptop', 'Laptop', 'Mouse'],
    'Sales': [5000, 8000, 200, 150, 6000, 7000, 300],
    'Quantity': [5, 8, 10, 5, 6, 7, 3]
}
data= pd.DataFrame(data)

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity
# 0       Alice  North  Laptop   5000         5
# 1         Bob  North  Laptop   8000         8
# 2       Alice  South   Mouse    200        10
# 3     Charlie  South   Mouse    150         5
# 4         Bob  North  Laptop   6000         6
# 5     Charlie  South  Laptop   7000         7
# 6       Alice  North   Mouse    300         3

# %%
pd.pivot_table(data,index='Product',columns='Region',values='Sales',aggfunc='mean',fill_value=0)
# Out:
# Region         North   South
# Product
# Laptop   6333.333333  7000.0
# Mouse     300.000000   175.0

# %%
data.shape
# Out:
# (7, 5)

# %%
data.size
# Out:
# 35

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Salesperson  7 non-null      object
#  1   Region       7 non-null      object
#  2   Product      7 non-null      object
#  3   Sales        7 non-null      int64
#  4   Quantity     7 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity
# 0       Alice  North  Laptop   5000         5
# 1         Bob  North  Laptop   8000         8
# 2       Alice  South   Mouse    200        10
# 3     Charlie  South   Mouse    150         5
# 4         Bob  North  Laptop   6000         6
# 5     Charlie  South  Laptop   7000         7
# 6       Alice  North   Mouse    300         3

# %%
data.columns
# Out:
# Index(['Salesperson', 'Region', 'Product', 'Sales', 'Quantity'], dtype='object')

# %%
data.sort_values('Quantity',ascending=True)
# Out:
#   Salesperson Region Product  Sales  Quantity
# 6       Alice  North   Mouse    300         3
# 0       Alice  North  Laptop   5000         5
# 3     Charlie  South   Mouse    150         5
# 4         Bob  North  Laptop   6000         6
# 5     Charlie  South  Laptop   7000         7
# 1         Bob  North  Laptop   8000         8
# 2       Alice  South   Mouse    200        10

# %%
data.groupby('Region')['Sales'].sum()
# Out:
# Region
# North    19300
# South     7350
# Name: Sales, dtype: int64

# %%
data.groupby(['Product','Region'])[['Sales','Quantity']].mean()
# Out:
#                       Sales  Quantity
# Product Region
# Laptop  North   6333.333333  6.333333
#         South   7000.000000  7.000000
# Mouse   North    300.000000  3.000000
#         South    175.000000  7.500000

# %%
data.value_counts()
# Out:
# Salesperson  Region  Product  Sales  Quantity
# Alice        North   Laptop   5000   5           1
#                      Mouse    300    3           1
#              South   Mouse    200    10          1
# Bob          North   Laptop   6000   6           1
#                               8000   8           1
# Charlie      South   Laptop   7000   7           1
#                      Mouse    150    5           1
# Name: count, dtype: int64

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity
# 0       Alice  North  Laptop   5000         5
# 1         Bob  North  Laptop   8000         8
# 2       Alice  South   Mouse    200        10
# 3     Charlie  South   Mouse    150         5
# 4         Bob  North  Laptop   6000         6
# 5     Charlie  South  Laptop   7000         7
# 6       Alice  North   Mouse    300         3

# %%
data["Sales"].apply( lambda x: x-100)
# Out:
# 0    4900
# 1    7900
# 2     100
# 3      50
# 4    5900
# 5    6900
# 6     200
# Name: Sales, dtype: int64

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity
# 0       Alice  North  Laptop   5000         5
# 1         Bob  North  Laptop   8000         8
# 2       Alice  South   Mouse    200        10
# 3     Charlie  South   Mouse    150         5
# 4         Bob  North  Laptop   6000         6
# 5     Charlie  South  Laptop   7000         7
# 6       Alice  North   Mouse    300         3

# %%
data['Revenue']= data['Sales'] * data['Quantity']

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity  Revenue
# 0       Alice  North  Laptop   5000         5    25000
# 1         Bob  North  Laptop   8000         8    64000
# 2       Alice  South   Mouse    200        10     2000
# 3     Charlie  South   Mouse    150         5      750
# 4         Bob  North  Laptop   6000         6    36000
# 5     Charlie  South  Laptop   7000         7    49000
# 6       Alice  North   Mouse    300         3      900

# %%
totalR=data['Revenue'].sum()

# %%
print(totalR)
# Out:
# 177650

# %%
def mani(x):
    if x==8000:
      x+=1000
    print('changes')
    return x

# %%
data['Sales'] = data['Sales'].apply(mani)
# Out:
# changes
# changes
# changes
# changes
# changes
# changes
# changes

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity  Revenue
# 0       Alice  North  Laptop   5000         5    25000
# 1         Bob  North  Laptop   9000         8    64000
# 2       Alice  South   Mouse    200        10     2000
# 3     Charlie  South   Mouse    150         5      750
# 4         Bob  North  Laptop   6000         6    36000
# 5     Charlie  South  Laptop   7000         7    49000
# 6       Alice  North   Mouse    300         3      900

# %%
data.loc[2,'Sales']+=200

# %%
data
# Out:
#   Salesperson Region Product  Sales  Quantity  Revenue
# 0       Alice  North  Laptop   5000         5    25000
# 1         Bob  North  Laptop   9000         8    64000
# 2       Alice  South   Mouse    400        10     2000
# 3     Charlie  South   Mouse    350         5      750
# 4         Bob  North  Laptop   6000         6    36000
# 5     Charlie  South  Laptop   7000         7    49000
# 6       Alice  North   Mouse    300         3      900

# %%
data['Quantity']=data['Quantity'].apply(lamda x: x+200)
# Out:
#   Cell In[2], line 1
#     data['Quantity']=data['Quantity'].apply(lamda x: x+200)
#                                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
